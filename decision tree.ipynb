# %%
import pandas as pd

# %%
df = pd.read_csv("salaries.csv")
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k  Unnamed: 4
# 0  google  computer programmer  bachelors                    0.0         NaN
# 1  google  computer programmer    masters                    0.0         NaN
# 2  google  computer programmer  bachelors                    1.0         NaN
# 3  google  computer programmer    masters                    1.0         NaN
# 4  google  computer programmer  bachelors                    0.0         NaN

# %%
df=df.drop(['Unnamed: 4'],axis=1)
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google  computer programmer  bachelors                    0.0
# 1  google  computer programmer    masters                    0.0
# 2  google  computer programmer  bachelors                    1.0
# 3  google  computer programmer    masters                    1.0
# 4  google  computer programmer  bachelors                    0.0

# %%
inputs = df.drop('salary_more_then_100k',axis='columns')

# %%
target = df['salary_more_then_100k']

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs
# Out:
#        company                  job     degree  company_n  job_n  degree_n
# 0       google  computer programmer  bachelors          2      0         0
# 1       google  computer programmer    masters          2      0         1
# 2       google  computer programmer  bachelors          2      0         0
# 3       google  computer programmer    masters          2      0         1
# 4       google  computer programmer  bachelors          2      0         0
# 5       google  computer programmer    masters          2      0         1
# 6   abc pharma  computer programmer    masters          0      0         1
# 7   abc pharma  computer programmer  bachelors          0      0         0
# 8   abc pharma  computer programmer  bachelors          0      0         0
# 9   abc pharma  computer programmer    masters          0      0         1
# 10    facebook  computer programmer  bachelors          1      0         0
# 11    facebook  computer programmer    masters          1      0         1
# 12    facebook  computer programmer  bachelors          1      0         0
# 13    facebook  computer programmer    masters          1      0         1
# 14    facebook  computer programmer  bachelors          1      0         0
# 15    facebook  computer programmer    masters          1      0         1
# 16         NaN                  NaN        NaN          3      1         2

# %%
inputs_n = inputs.drop(['company','job','degree'],axis='columns')

# %%
inputs_n
# Out:
#     company_n  job_n  degree_n
# 0           2      0         0
# 1           2      0         1
# 2           2      0         0
# 3           2      0         1
# 4           2      0         0
# 5           2      0         1
# 6           0      0         1
# 7           0      0         0
# 8           0      0         0
# 9           0      0         1
# 10          1      0         0
# 11          1      0         1
# 12          1      0         0
# 13          1      0         1
# 14          1      0         0
# 15          1      0         1
# 16          3      1         2

# %%
target
# Out:
# 0     0.0
# 1     0.0
# 2     1.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     0.0
# 8     0.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    NaN
# Name: salary_more_then_100k, dtype: float64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.fit(inputs_n, target)
#
# File E:\anaconda\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File E:\anaconda\lib\site-packages\sklearn\tree\_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     184 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186 X, y = self._validate_data(
#     187     X, y, validate_separately=(check_X_params, check_y_params)
#     188 )
#     189 if issparse(X):
#     190     X.sort_indices()
#
# File E:\anaconda\lib\site-packages\sklearn\base.py:563, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     561     if "estimator" not in check_y_params:
#     562         check_y_params = {**default_check_params, **check_y_params}
# --> 563     y = check_array(y, input_name="y", **check_y_params)
#     564 else:
#     565     X, y = check_X_y(X, y, **check_params)
#
# File E:\anaconda\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File E:\anaconda\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.
